# %% [markdown]
# The provided code stub reads two integers from STDIN,  and . Add code to print three lines where:
#
# - The first line contains the sum of the two numbers.
# - The second line contains the difference of the two numbers (first - second).
# - The third line contains the product of the two numbers.

# %% [markdown]
# O trecho de código fornecido lê dois números inteiros da entrada STDIN.Adicione um código que imprima 3 linhas onde:
# - a primeira linha contenha a soma dos dois números;
# - a segunda linha contenha a diferença dos dois números;
# - e a terceira linha contenha o produto dos dois números;

# %%
a = int(input())
b = int(input())

soma = a + b
diferenca = a - b
multiplicacao = a * b

print(soma)
print(diferenca)
print(multiplicacao)
# Out:
# 8
# -2
# 15
