# %% [markdown]
# The provided code stub reads two integers,  and , from STDIN.
#
# Add logic to print two lines. The first line should contain the result of integer division,  // . The second line should contain the result of float division,  / .
#
# No rounding or formatting is necessary.

# %% [markdown]
# Crie um código que leia dois inteiros e imprima duas linhas:
# - A primeira linha deve conter o resultado da divisão (inteiro)
# - A segunda linha deve conter o resultado da divisão (float)

# %%
a = int(input())
b = int(input())

divisao = a/b

print(int(divisao))
print(float(divisao))
# Out:
# 1
# 1.6666666666666667
