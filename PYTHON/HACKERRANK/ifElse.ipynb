# %% [markdown]
# Given an integer "n", perform the following conditional actions:
#
# - If n is odd, print Weird
# - If n is even and in the inclusive range of 2 to 5, print Not Weird
# - If n is even and in the inclusive range of 6 to 20, print Weird
# - If n is even and greater than 20, print Not Weird
#
# Input Format
#
# A single line containing a positive integer, n.
#
# Constraints
#
# 1 <= n <= 100
#
# Output Format
#
# Print Weird if the number is weird. Otherwise, print Not Weird.

# %% [markdown]
# Dado um inteiro "n", execute a seguinte ação condicional:
#
# - Se n for ímpar, print Weird
# - Se n for par e esta entre 2 e 5, print Not Weird
# - Se n for par e esta entre 6 e 20, print Weird
# - Se n for par e maior que 20, print Not Weird
#
# Input Format
#
# Uma linha simples contendo um inteiro positivo, n.
#
# Restrição
#
# 1 <= n <= 100

# %%
n = int(input().strip())

if n % 2 != 0:
    print("Weird")
elif 2 <= n <= 5:
    print("Not Weird")
elif 6 <= n <= 20:
    print("Weird")
else:
    print("Not Weird")
# Out:
# Weird
