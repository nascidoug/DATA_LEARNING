# %% [markdown]
# The provided code stub reads an integer, , from STDIN. For all non-negative integers , print .

# %% [markdown]
# Crie um código que lê um inteiro "n" e retorne uma lista dos números inteiros positivos menores que "n"

# %%
n = int(input())

for i in range(n):
    print(i ** 2)
# Out:
# 0
# 1
# 4
# 9
# 16
